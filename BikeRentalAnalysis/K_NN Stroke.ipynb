# %% [markdown]
# # 5.6 최근접 이웃(KNN) 분류 모델

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/drive/MyDrive/기말고사 과제/Bike-standard.csv')
df.shape

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8751 entries, 0 to 8750
# Data columns (total 47 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Temperature      8751 non-null   float64
#  1   Humidity         8751 non-null   float64
#  2   Wind speed       8751 non-null   float64
#  3   Visibility       8751 non-null   float64
#  4   Solar Radiation  8751 non-null   float64
#  5   Rented Bike B    8751 non-null   float64
#  6   Functioning Day  8751 non-null   int64
#  7   Holiday          8751 non-null   int64
#  8   Date_1.0         8751 non-null   int64
#  9   Date_2.0         8751 non-null   int64
#  10  Date_3.0         8751 non-null   int64
#  11  Date_4.0         8751 non-null   int64
#  12  Date_5.0         8751 non-null   int64
#  13  Date_6.0         8751 non-null   int64
#  14  Date_7.0         8751 non-null   int64
#  15  Date_8.0         8751 non-null   int64
#  16  Date_9.0         8751 non-null   int64
#  17  Date_10.0        8751 non-null   int64
#  18  Date_11.0        8751 non-null   int64
#  19  Date_12.0        8751 non-null   int64
#  20  Date_13.0        8751 non-null   int64
#  21  Hour_1.0         8751 non-null   int64
#  22  Hour_2.0         8751 non-null   int64
#  23  Hour_3.0         8751 non-null   int64
#  24  Hour_4.0         8751 non-null   int64
#  25  Hour_5.0         8751 non-null   int64
#  26  Hour_6.0         8751 non-null   int64
#  27  Hour_7.0         8751 non-null   int64
#  28  Hour_8.0         8751 non-null   int64
#  29  Hour_9.0         8751 non-null   int64
#  30  Hour_10.0        8751 non-null   int64
#  31  Hour_11.0        8751 non-null   int64
#  32  Hour_12.0        8751 non-null   int64
#  33  Hour_13.0        8751 non-null   int64
#  34  Hour_14.0        8751 non-null   int64
#  35  Hour_15.0        8751 non-null   int64
#  36  Hour_16.0        8751 non-null   int64
#  37  Hour_17.0        8751 non-null   int64
#  38  Hour_18.0        8751 non-null   int64
#  39  Hour_19.0        8751 non-null   int64
#  40  Hour_20.0        8751 non-null   int64
#  41  Hour_21.0        8751 non-null   int64
#  42  Hour_22.0        8751 non-null   int64
#  43  Hour_23.0        8751 non-null   int64
#  44  Seasons_1.0      8751 non-null   int64
#  45  Seasons_2.0      8751 non-null   int64
#  46  Seasons_3.0      8751 non-null   int64
# dtypes: float64(6), int64(41)
# memory usage: 3.1 MB

# %%
data = df.drop(['Rented Bike B'], axis=1)   # 타겟변수를 제외한 변수만 data에 저장
target = df['Rented Bike B']                # 타겟변수만 target에 저장

# %%
# 50:50 데이터 분할
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    data, target, test_size=0.5, random_state=42, stratify=target)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (4375, 46)
# X_test shape: (4376, 46)

# %%
# 참조 코딩
print(X_train)
# Out:
#       Temperature  Humidity  Wind speed  Visibility  Solar Radiation  \
# 7838    -0.140773  0.971083   -1.187800   -1.043819        -0.655063
# 3800     0.763391 -0.846273   -0.021196    0.925668         1.693727
# 7351     0.930829 -1.190097    0.950973    0.925668         1.210153
# 3624     0.495490  0.872848   -1.090583   -1.867453        -0.240570
# 5022     1.190357  0.676377    1.242624   -0.511170         0.392682
# ...           ...       ...         ...         ...              ...
# 6129     1.701042 -0.158625    0.950973    0.268076        -0.021810
# 3247     0.051780 -0.600684    1.631492   -0.184018         2.465144
# 3066    -0.760293 -0.944508    1.437058    0.925668        -0.655063
# 3852     0.060152  1.167554    0.367671   -1.507421        -0.632035
# 2587    -0.400302  0.872848   -0.896149   -1.553453        -0.655063
#
#       Functioning Day  Holiday  Date_1.0  Date_2.0  Date_3.0  ...  Hour_17.0  \
# 7838                1        1         0         0         0  ...          0
# 3800                1        1         0         0         0  ...          0
# 7351                1        0         0         1         0  ...          0
# 3624                1        0         0         0         0  ...          0
# 5022                1        1         0         0         0  ...          0
# ...               ...      ...       ...       ...       ...  ...        ...
# 6129                1        1         0         0         0  ...          1
# 3247                1        1         0         0         0  ...          0
# 3066                1        1         0         0         0  ...          0
# 3852                0        1         0         0         0  ...          0
# 2587                1        1         0         0         0  ...          0
#
#       Hour_18.0  Hour_19.0  Hour_20.0  Hour_21.0  Hour_22.0  Hour_23.0  \
# 7838          0          0          0          0          0          1
# 3800          0          0          0          0          0          0
# 7351          0          0          0          0          0          0
# 3624          0          0          0          0          0          0
# 5022          0          0          0          0          0          0
# ...         ...        ...        ...        ...        ...        ...
# 6129          0          0          0          0          0          0
# 3247          0          0          0          0          0          0
# 3066          0          0          0          1          0          0
# 3852          0          0          1          0          0          0
# 2587          0          0          0          0          1          0
#
#       Seasons_1.0  Seasons_2.0  Seasons_3.0
# 7838            0            0            0
# 3800            1            0            0
# 7351            0            0            0
# 3624            1            0            0
# 5022            0            1            0
# ...           ...          ...          ...
# 6129            0            1            0
# 3247            1            0            0
# 3066            1            0            0
# 3852            1            0            0
# 2587            1            0            0
#
# [4375 rows x 46 columns]

# %%
# KNN 모델 (Default 모델 with n_neighbors=3)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

clf_knn = KNeighborsClassifier(n_neighbors=3) # random_state 파라미터가 없음에 주의!
clf_knn.fit(X_train, y_train)
pred = clf_knn.predict(X_test)   # 학습된 Classifier로 테스트 데이터셋 자료이용해서 타겟변수 예측값 생성
accuracy = accuracy_score(y_test, pred)

print ("KNN Training set score:{:.5f}".format(clf_knn.score(X_train, y_train)))
print ("KNN Test set score:{:.5f}".format(accuracy_score(y_test, pred)))
# Out:
# KNN Training set score:0.93920
# KNN Test set score:0.87454

# %%
# KNN 모델 (Default 모델 with n_neighbors=3)
clf_knn = KNeighborsClassifier(n_neighbors=3) # random_state 파라미터가 없음에 주의!

# 그리드 서치 실행
from sklearn.model_selection import GridSearchCV
params = {'n_neighbors': range(3, 31)}

grid_knn = GridSearchCV(clf_knn, param_grid=params, scoring='accuracy', cv=3, n_jobs=-1)
grid_knn.fit(X_train, y_train)

print("GridSearchCV max accuracy:{:.5f}".format(grid_knn.best_score_))
print("GridSearchCV best parameter:", (grid_knn.best_params_))
# Out:
# GridSearchCV max accuracy:0.88046
# GridSearchCV best parameter: {'n_neighbors': 5}

# %%
best_clf = grid_knn.best_estimator_
pred = best_clf.predict(X_test)
print("Accuracy on test set:{:.5f}".format(accuracy_score(y_test, pred)))
# Out:
# Accuracy on test set:0.88551
